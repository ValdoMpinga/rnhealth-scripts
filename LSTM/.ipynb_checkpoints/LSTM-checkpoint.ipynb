# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
from datetime import timezone, datetime
import seaborn as sns
from matplotlib import pyplot as plt
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

os.environ['KMP_DUPLICATE_LIB_OK']='True'
import absl.logging
absl.logging.set_verbosity(absl.logging.ERROR)

# %%
imputedMeasurementsDf = pd.read_csv('../../../../Data/ProcessedData/Interpolation/interpolatedMeasurementsDf.csv')

# %%
imputedMeasurementsDf = pd.read_csv('./../../../../Data/ProcessedData/Interpolation/interpolatedMeasurementsDf.csv')
imputedMeasurementsDf = pd.DataFrame(imputedMeasurementsDf)
imputedMeasurementsDf['time'] =  pd.to_datetime(imputedMeasurementsDf['time'], format='%Y-%m-%d %H:%M:%S')
imputedMeasurementsDf.index = imputedMeasurementsDf['time']
imputedMeasurementsDf = imputedMeasurementsDf.drop(['time'],axis = 1)

# %%
imputedMeasurementsDf.head(20)
# Out:
#                        T      Rn    H           P         CO2
# time
# 2019-05-15 15:00:00  0.0  3696.3  0.0  101.219889  184.833333
# 2019-05-15 16:00:00  0.0  3696.3  0.0  101.221692  179.230769
# 2019-05-15 17:00:00  0.0  3696.3  0.0  101.226687  184.875000
# 2019-05-15 18:00:00  0.0  3696.3  0.0  101.249615  184.423077
# 2019-05-15 19:00:00  0.0  3696.3  0.0  101.283528  184.811321
# 2019-05-15 20:00:00  0.0  3696.3  0.0  101.310269  180.538462
# 2019-05-15 21:00:00  0.0  3696.3  0.0  101.343435  185.869565
# 2019-05-15 22:00:00  0.0  3696.3  0.0  101.320302  185.622642
# 2019-05-15 23:00:00  0.0  3696.3  0.0  101.293077  187.480769
# 2019-05-16 00:00:00  0.0  3696.3  0.0  101.253906  184.905660
# 2019-05-16 01:00:00  0.0  3696.3  0.0  101.203863  184.470588
# 2019-05-16 02:00:00  0.0  3696.3  0.0  101.173792  182.849057
# 2019-05-16 03:00:00  0.0  3696.3  0.0  101.165093  180.481481
# 2019-05-16 04:00:00  0.0  3696.3  0.0  101.165020  183.940000
# 2019-05-16 05:00:00  0.0  3696.3  0.0  101.184558  180.596154
# 2019-05-16 06:00:00  0.0  3696.3  0.0  101.193226  186.188679
# 2019-05-16 07:00:00  0.0  3696.3  0.0  101.212385  184.961538
# 2019-05-16 08:00:00  0.0  3696.3  0.0  101.229442  183.846154
# 2019-05-16 09:00:00  0.0  3696.3  0.0  101.246132  185.490566
# 2019-05-16 10:00:00  0.0  3696.3  0.0  101.242333  187.500000

# %%
measurementsDf.index =measurementsDf['time']

# %%
measurementsDf['Rn'].plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
RadonDf =pd.DataFrame( measurementsDf['Rn'])
RadonDf
# Out:
#                               Rn
# time
# 2020-07-14 14:00:00  1001.448424
# 2020-07-14 15:00:00   588.154974
# 2020-07-14 16:00:00     0.100000
# 2020-07-14 17:00:00  1042.843803
# 2020-07-14 18:00:00  1585.713833
# ...                          ...
# 2021-12-31 19:00:00   616.640000
# 2021-12-31 20:00:00   541.380000
# 2021-12-31 21:00:00   544.167273
# 2021-12-31 22:00:00   590.666000
# 2021-12-31 23:00:00   594.030000
#
# [115634 rows x 1 columns]

# %%
RadonDf['H'] = measurementsDf['H']
RadonDf['CO2'] = measurementsDf['CO2']
RadonDf['P'] = measurementsDf['P']
RadonDf['T'] = measurementsDf['T']
RadonDf
# Out:
#                               Rn          H         CO2           P          T
# time
# 2020-07-14 14:00:00  1001.448424  44.475000  567.750000  101.565847  31.300000
# 2020-07-14 15:00:00   588.154974  45.505556  636.361111  101.632854  31.333333
# 2020-07-14 16:00:00     0.100000  47.145714  734.000000  101.539128  31.451429
# 2020-07-14 17:00:00  1042.843803  36.000000  461.529412  101.501998  31.161765
# 2020-07-14 18:00:00  1585.713833  28.436111  400.000000  101.567130  31.008333
# ...                          ...        ...         ...         ...        ...
# 2021-12-31 19:00:00   616.640000  50.156364   97.200000  102.653100  29.792673
# 2021-12-31 20:00:00   541.380000  48.047273   97.800000  102.273400  29.951673
# 2021-12-31 21:00:00   544.167273  53.847273   97.181818  102.199727  30.329218
# 2021-12-31 22:00:00   590.666000  44.097576   98.100000  102.140000  29.511200
# 2021-12-31 23:00:00   594.030000  41.082424   98.090909  102.145091  30.079564
#
# [115634 rows x 5 columns]

# %%
from sklearn.metrics import mean_squared_error as mse

def predictions_plotter(model, X, y, start=0, end=100):
    predictions = model.predict(X).flatten()
    df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
    plt.plot(df['Predictions'][start:end])
    plt.plot(df['Actuals'][start:end])
    return df, mse(y, predictions)

# %%
#Converts the Df to a numpy array and then extracts the X and y value
#on the required format to train the model
def df_to_X_y(df, window_size=6):
    df_as_np = df.to_numpy() # converts the dataframe to a numpy array
    #Initialized  arrays to append X and Y values 
    X = []
    y = []
    for i in range(len(df_as_np)-window_size):
        #Takes values from i to i + win size
        row =  [r for r in df_as_np[i:i+window_size]]
        X.append(row)
        #The final output
        label = df_as_np[i+window_size][0]
        y.append(label)
    return np.array(X), np.array(y)

# %%
X1, y1 = df_to_X_y(RadonDf)
X1.shape, y1.shape
# Out:
# ((115628, 6, 5), (115628,))

# %%
X_train, y_train = X1[:92508], y1[:92508] # training data
X_val, y_val = X1[92508:95508], y1[92508:95508] #validation
X_test, y_test = X1[95508:], y1[95508:] #test
X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((92508, 6, 5), (92508,), (3000, 6, 5), (3000,), (20120, 6, 5), (20120,))

# %% [markdown]
#  <h2> <font color='red'> LSTM implementation </font> <h2/>

# %%
from keras import backend as K

def soft_acc(y_true, y_pred):
    return K.mean(K.equal(K.round(y_true), K.round(y_pred)))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError,MeanAbsoluteError
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(InputLayer((6, 5)))
model.add(LSTM(64))
model.add(Dense(8, 'relu'))
model.add(Dense(1, 'linear'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 64)                17920
# _________________________________________________________________
# dense (Dense)                (None, 8)                 520
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 18,449
# Trainable params: 18,449
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp = ModelCheckpoint('LSTM_model/', save_best_only=True)
model.compile(loss=MeanSquaredError(), 
               optimizer=Adam(learning_rate=0.0001), 
               metrics=[MeanAbsoluteError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# 2891/2891 [==============================] - 27s 7ms/step - loss: 1609864.8750 - mean_absolute_error: 663.3605 - val_loss: 277287.2188 - val_mean_absolute_error: 450.780141.3750  - ETA: 7s - loss: 1633423.6250 - mean_abs -
# INFO:tensorflow:Assets written to: LSTM_model\assets
# INFO:tensorflow:Assets written to: LSTM_model\assets
# Epoch 2/10
# 2891/2891 [==============================] - 19s 7ms/step - loss: 1495486.1250 - mean_absolute_error: 596.1357 - val_loss: 185705.5312 - val_mean_absolute_error: 345.2557
# INFO:tensorflow:Assets written to: LSTM_model\assets
# INFO:tensorflow:Assets written to: LSTM_model\assets
# Epoch 3/10
# 2891/2891 [==============================] - 19s 6ms/step - loss: 1352483.6250 - mean_absolute_error: 522.9536 - val_loss: 103498.9531 - val_mean_absolute_error: 233.0021
# INFO:tensorflow:Assets written to: LSTM_model\assets
# INFO:tensorflow:Assets written to: LSTM_model\assets
# Epoch 4/10
# 2891/2891 [==============================] - 20s 7ms/step - loss: 1198332.2500 - mean_absolute_error: 458.2998 - val_loss: 45406.1289 - val_mean_absolute_error: 133.4962
# INFO:tensorflow:Assets written to: LSTM_model\assets
# INFO:tensorflow:Assets written to: LSTM_model\assets
# Epoch 5/10
# 2891/2891 [==============================] - 20s 7ms/step - loss: 1039717.6250 - mean_absolute_error: 407.4107 - val_loss: 18435.2832 - val_mean_absolute_error: 71.2904
# INFO:tensorflow:Assets written to: LSTM_model\assets
# INFO:tensorflow:Assets written to: LSTM_model\assets
# Epoch 6/10
# 2891/2891 [==============================] - 17s 6ms/step - loss: 879737.4375 - mean_absolute_error: 367.5251 - val_loss: 11536.1309 - val_mean_absolute_error: 56.1704
# INFO:tensorflow:Assets written to: LSTM_model\assets
# INFO:tensorflow:Assets written to: LSTM_model\assets
# Epoch 7/10
# 2891/2891 [==============================] - 18s 6ms/step - loss: 720381.6875 - mean_absolute_error: 332.7832 - val_loss: 9567.5869 - val_mean_absolute_error: 53.8393
# INFO:tensorflow:Assets written to: LSTM_model\assets
# INFO:tensorflow:Assets written to: LSTM_model\assets
# Epoch 8/10
# 2891/2891 [==============================] - 17s 6ms/step - loss: 561847.3125 - mean_absolute_error: 297.6572 - val_loss: 10049.5977 - val_mean_absolute_error: 60.1129
# Epoch 9/10
# 2891/2891 [==============================] - 18s 6ms/step - loss: 416092.3438 - mean_absolute_error: 262.0115 - val_loss: 9152.6787 - val_mean_absolute_error: 54.3339
# INFO:tensorflow:Assets written to: LSTM_model\assets
# INFO:tensorflow:Assets written to: LSTM_model\assets
# Epoch 10/10
# 2891/2891 [==============================] - 16s 5ms/step - loss: 287155.2188 - mean_absolute_error: 225.2753 - val_loss: 9560.7549 - val_mean_absolute_error: 58.5089

# %%
model = load_model('LSTM_model/')

# %%
model.evaluate(X_test,y_test)
# Out:
# 629/629 [==============================] - 3s 3ms/step - loss: 105678.5078 - mean_absolute_error: 105.2144
# [105678.5078125, 105.21442413330078]

# %%
train_predictions = model.predict(X_train).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train})

# %%
train_results.head(30)
# Out:
#     Train Predictions      Actuals
# 0         1505.179077  1585.713833
# 1         1512.697754  1585.713833
# 2         1462.530151  1585.713833
# 3         1455.598267  1389.856833
# 4         1283.067017  1037.712333
# 5          982.943542   423.906944
# 6          430.446686   578.023500
# 7          706.962830   706.933161
# 8          772.158325   706.933161
# 9          785.313660   423.906944
# 10         455.961304   578.657079
# 11         731.682678   429.695167
# 12         463.272125   201.446045
# 13         363.405182   124.072324
# 14         198.890488   127.271500
# 15         181.852249    30.880515
# 16         152.943115    30.567742
# 17         141.125961    30.567742
# 18          79.852905    33.053167
# 19           9.698857    33.053167
# 20          11.806103    30.880515
# 21           4.662960    30.880515
# 22           5.595518    22.999675
# 23           4.694392    11.440188
# 24           3.314767    14.084856
# 25           1.166888    22.580115
# 26           1.139771     0.118000
# 27          28.646456     0.100000
# 28          24.893557   421.920500
# 29         427.174225    22.617312

# %%
plt.style.use('seaborn')

# %%
plt.plot(train_results['Train Predictions'][:1000],)
plt.plot(train_results['Actuals'][:1000])
plt.legend(['Train Predictions','Actuals'])

# %%
val_predictions = model.predict(X_val).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val
# 274.2655553089488
# 142.6109708658854
# 112.52677978515624
# 538.8184448242188
# 1084.0894580078125
# 251.48979654947925
# 108.97725075461642
# 643.9440844726563
# 127.86263169508715
# 106.26902521306829
# 110.98062566583803
# 275.34732088955974
# 202.927383219401
# 114.6003361002604
# 125.45857100053274
# 100.3398659446022
# 119.13712502219454
# 107.27784912109371
# 117.5013728841144
# 110.12529940518459
# 103.6106901411577
# 117.43286499023435
# 145.91004949396307
# 104.68944025213057
# 149.65142333984357
# 135.51312093098954
# 195.24848958333342
# 420.847529185902
# 105.06979614257813
# 120.56484944661452
# 165.99259787819608
# 126.79940511067718
# 147.1550170898438
# 126.85509358723954
# 111.96516601562507
# 136.37845621744793
# 131.98839192708323
# 120.43044677734395
# 107.79631347656243
# 192.04541178385432
# 185.10052867542606
# 169.31069458007818
# 188.81468217329544

# %%
len(results)
# Out:
# 2809

# %%
resultSum = sum(results)

# %%
resultSum/(len(results))
# Out:
# 10.521789224433084

# %%
val_results.head(30)
# Out:
#     Val Predictions     Actuals
# 0        419.634338  469.725455
# 1        455.312988  438.566667
# 2        391.271881  419.945000
# 3        391.474091  434.873333
# 4        410.744110  421.390909
# 5        388.601349  441.125000
# 6        418.278351    0.240000
# 7        101.375275  355.225000
# 8        485.126160  475.210000
# 9        507.098480  616.751667
# 10       665.588074  815.600000
# 11       838.893250  740.680000
# 12       692.050110  589.110000
# 13       579.118591  547.795000
# 14       546.759155  454.120000
# 15       428.580475  496.222500
# 16       511.096344  410.768333
# 17       400.634430  366.231667
# 18       362.625580  333.031818
# 19       292.341766  266.213333
# 20       214.742020  277.005000
# 21       276.996674  275.745455
# 22       258.604523  242.883333
# 23       211.793045  250.255000
# 24       244.816772  212.188333
# 25       196.752289  211.830909
# 26       212.504852  237.550000
# 27       239.925690  258.320000
# 28       263.449585  313.220000
# 29       328.565613  324.066667

# %%
plt.plot(val_results['Val Predictions'][:1000])
plt.plot(val_results['Actuals'][:1000])
plt.legend(['Predictions values','Actuals'])

# %%
test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test})

# %%
test_results.head(30)
# Out:
#     Test Predictions     Actuals
# 0         923.916199  862.405000
# 1         794.455872  841.680000
# 2         809.434143  854.633333
# 3         825.854187  853.469000
# 4         826.928284  890.230000
# 5         928.899353  815.413333
# 6         757.593323  811.605455
# 7         786.438049  804.932500
# 8         762.791809  808.569167
# 9         775.509216  822.270909
# 10        778.338928  844.027500
# 11        814.407776  759.144167
# 12        726.282410  758.683333
# 13        737.030579  807.364545
# 14        785.501038  775.544167
# 15        741.448059  849.328333
# 16        840.304382  825.800909
# 17        784.982483  787.048333
# 18        752.767151  830.705000
# 19        819.066284  860.884545
# 20        830.629089  919.902500
# 21        931.444031  858.702500
# 22        801.500549  794.506667
# 23        751.881531  798.085455
# 24        781.791992  772.648333
# 25        733.925598  783.946667
# 26        758.331726  852.475455
# 27        849.408020  843.380833
# 28        789.533325  805.082500
# 29        752.552185  779.420000

# %%
plt.plot(test_results['Test Predictions'][:1000])
plt.plot(test_results['Actuals'][:1000])
plt.legend(['Test values','Actuals'])
